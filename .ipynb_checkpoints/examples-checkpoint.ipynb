# %%
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
import numpy as np
import mobilityapp as ma

# %% [markdown]
# # Step by step

# %% [markdown]
# ## Import and arrange data

# %%
data=np.loadtxt('exampledata.dat')

Vg=data[0][::-1]
G=data[1]*7.748091729e-5 # This data was recorded in units of 2e2/h, but we need S.

if Vg[-1]<Vg[0]:  #The fitting functions get angry if Vg isn't ascending. 
    Vg=Vg[::-1]
    G=G[::-1]
    
plt.plot(Vg,G)
plt.xlabel('Vg (V)')
plt.ylabel('Conductance (S)')
plt.show()

# %% [markdown]
# ## Take the derivative, perform a fit to find the inflection point

# %%
# When taking a numerical derivative, it's often necessary to smooth the data to avoid noise dominating
# To make it easy to understand, we can normalise the smoothing amount to the gate voltage range,
# i.e. smoothing should be a number between 0 and 1

smoothing = 0.1

if smoothing!=0:
    Gsmooth=savgol_filter(G, int(G.shape[0]*smoothing), 5, deriv=0, delta=1.0, axis=-1, mode='interp', cval=0.0)
    dGdVg = np.gradient(Gsmooth, Vg)
else:
    Gmooth=0 #Necessary later because I'm not a good developer, sorry
    dGdVg = np.gradient(G, Vg)

# If you need to restrict the data to a particular Vg range, specify it here. Otherwise write Vmin='Min', Vmax='Max'
Vmin=-4  #'Min'
Vmax=4  #'Max'

#We now can send all the information to the function that performs the fit, and get a bunch of information back
V0,Vth,Vg_infl,V_Rs,inflectionline,deriv_fit,result_deriv_fit=ma.perform_deriv_fit(Vg,G,dGdVg,Gsmooth,smoothing,Vmin=Vmin,Vmax=Vmax)

# Plot both the fit and the line tangential to the inflection point to make sure it looks sensible.
# It's really important to check here that the tangent line looks sensible. Any error here can propagate.
# If it looks bad, perhaps you need to change the amount of smoothing, or the gate range.

plt.plot(Vg,dGdVg)
plt.plot(Vg,deriv_fit)
plt.xlabel('Vg (V)')
plt.ylabel('$dG/dVg$ (S/V)')
plt.show()

plt.plot(Vg,G)
plt.plot(Vg,inflectionline)
plt.xlabel('Vg (V)')
plt.ylabel('Conductance (S)')
plt.ylim([G.min()-(G.max()-G.min())/10,G.max()+(G.max()-G.min())/10])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 19
#      16 Vmax=4  #'Max'
#      18 #We now can send all the information to the function that performs the fit, and get a bunch of information back
# ---> 19 V0,Vth,Vg_infl,V_Rs,inflectionline,deriv_fit,result_deriv_fit=ma.perform_deriv_fit(Vg,G,dGdVg,Gsmooth,smoothing,Vmin=Vmin,Vmax=Vmax)
#      21 # Plot both the fit and the line tangential to the inflection point to make sure it looks sensible.
#      22 # It's really important to check here that the tangent line looks sensible. Any error here can propagate.
#      23 # If it looks bad, perhaps you need to change the amount of smoothing, or the gate range.
#      25 plt.plot(Vg,dGdVg)
#
# File C:\git\MobilityApp\mobilityapp\supportfunctions.py:109, in perform_deriv_fit(Vg, G, dGdVg, Gsmooth, smoothing, Vmin, Vmax)
#     106     return data - model_values
#     108 # Perform the fit using lmfit
# --> 109 result = minimize(residual, params, args=(Vg[min_ind:max_ind], dGdVg[min_ind:max_ind]))
#     111 # Generate two versions of the best-fit curve; one for plotting, one for extracting values more precisely
#     112 Vgfine=np.linspace(Vg[min_ind],Vg[max_ind],10001) #Makes the method more robust to sparse datasets.
#
# File ~\.conda\envs\mobility\Lib\site-packages\lmfit\minimizer.py:2586, in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, max_nfev, **fit_kws)
#    2446 """Perform the minimization of the objective function.
#    2447
#    2448 The minimize function takes an objective function to be minimized,
#    (...)
#    2580
#    2581 """
#    2582 fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#    2583                    iter_cb=iter_cb, scale_covar=scale_covar,
#    2584                    nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2585                    calc_covar=calc_covar, max_nfev=max_nfev, **fit_kws)
# -> 2586 return fitter.minimize(method=method)
#
# File ~\.conda\envs\mobility\Lib\site-packages\lmfit\minimizer.py:2330, in Minimizer.minimize(self, method, params, **kws)
#    2327         if (key.lower().startswith(user_method) or
#    2328                 val.lower().startswith(user_method)):
#    2329             kwargs['method'] = val
# -> 2330 return function(**kwargs)
#
# File ~\.conda\envs\mobility\Lib\site-packages\lmfit\minimizer.py:1649, in Minimizer.leastsq(self, params, max_nfev, **kws)
#    1647 result.call_kws = lskws
#    1648 try:
# -> 1649     lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1650 except AbortFitException:
#    1651     pass
#
# File ~\.conda\envs\mobility\Lib\site-packages\scipy\optimize\_minpack_py.py:438, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     436     if maxfev == 0:
#     437         maxfev = 200*(n + 1)
# --> 438     retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     439                              gtol, maxfev, epsfcn, factor, diag)
#     440 else:
#     441     if col_deriv:
#
# File ~\.conda\envs\mobility\Lib\site-packages\lmfit\minimizer.py:554, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     552     raise AbortFitException("fit aborted by user.")
#     553 else:
# --> 554     return coerce_float64(out, nan_policy=self.nan_policy)
#
# File ~\.conda\envs\mobility\Lib\site-packages\lmfit\minimizer.py:2430, in coerce_float64(arr, nan_policy, handle_inf, ravel, ravel_order)
#    2425     if contains_nan:
#    2426         msg = ('NaN values detected in your input data or the output of '
#    2427                'your objective/model function - fitting algorithms cannot '
#    2428                'handle this! Please read https://lmfit.github.io/lmfit-py/faq.html#i-get-errors-from-nan-in-my-fit-what-can-i-do '
#    2429                'for more information.')
# -> 2430         raise ValueError(msg)
#    2431 return arr
#
# ValueError: NaN values detected in your input data or the output of your objective/model function - fitting algorithms cannot handle this! Please read https://lmfit.github.io/lmfit-py/faq.html#i-get-errors-from-nan-in-my-fit-what-can-i-do for more information.

# %% [markdown]
# ## Find the series resistance

# %%
#To calculate the effective mobility and density, we need to know the series resistance Rs. 
#To find Rs, we use the Drude model only at large Vg, where Rs is large compared to the device resistance
#We now need to know a few more things...
L = 3.6e-6   #Device/gate length in meters
C = 5.3e-15  #Gate capacitance in farad
initial_Rs = 10000  #A rough guess for Rs in Ohm, to give the fit somewhere to start. 1/G_max is a good guess...
initial_mu = 0.4    #A rough guess for mu in m^2/(Vs). Note!! Not cm^2

Rs,Rs_fit,V_Rs_ind,result_drudeRs=ma.perform_Rs_fit(Vg,G,V0,V_Rs,initial_Rs,initial_mu,L,C)

#Check that the fit looks nice at large Rs. If not, try to change the initial guesses
plt.plot(Vg,G)
plt.plot(Vg[V_Rs_ind:],Rs_fit)
plt.xlabel('Vg (V)')
plt.ylabel('Conductance (S)')
plt.ylim([G.min()-(G.max()-G.min())/10,G.max()+(G.max()-G.min())/10])
plt.show()

# %% [markdown]
# ## Calculate effective mobility and density

# %%
#To calculate the density, we need to know the capacitance per area.
#If you have a rectangular device, and know the channel/gate width, it's easy
#If you have e.g. a backgated nanowire, you need to know the capacitance per area from a simulation/calculation.
#Uncomment the below as necessary

# CperA=5.2e-3

width=280e-9
CperA = C/(L*width)

density=CperA*(Vg-V0)/1.602176634e-19
mu_eff=L**2/(C*(Vg-V0)*((1/G)-Rs))

plotstart=(np.abs(Vg - (2*Vth-Vg_infl))).argmin()
plt.plot(density[plotstart:]*1e-12/1e4,mu_eff[plotstart:]*1e4)
plt.xlabel('Carrier density x 10$^{12}$ (cm$^{-2}$)')
plt.ylabel('Mobility (cm$^2$/(Vs))')
plt.show()
# Out:
# C:\Users\dc\AppData\Local\Temp\ipykernel_115848\1398555694.py:12: RuntimeWarning: divide by zero encountered in divide
#   mu_eff=L**2/(C*(Vg-V0)*((1/G)-Rs))

# %% [markdown]
# ## Perform a drude fit

# %%
# If you really want to do it the old way, you can.

mu_drude,drude_fit,Rs_drude,Vth_ind,result_drude=ma.perform_drude_fit(Vg,G,Vth,initial_Rs,initial_mu,L,C)

plt.plot(Vg,G)
plt.plot(Vg[Vth_ind:],drude_fit)
plt.xlabel('Vg (V)')
plt.ylabel('Conductance (S)')
plt.ylim([G.min()-(G.max()-G.min())/10,G.max()+(G.max()-G.min())/10])
plt.show()

result_drude 
#Note; the lmfit results were returned for each previous fit as well
#If the fitting isn't going well, it can be very helpful to print the fit results.
#It may help guide towards better initial guesses.
# Out:
# <h2>Fit Result</h2> <p>Model: Model(drude)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>29</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>393</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>3</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 3.9647e-09</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 1.0166e-11</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-9944.62267</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-9932.70124</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.97389902</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>Rs</td><td style='text-align:left'> 10092.3993</td><td style='text-align:left'> 40.1702955</td><td style='text-align:left'>(0.40%)</td><td style='text-align:left'>10000</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>mu</td><td style='text-align:left'> 0.76417337</td><td style='text-align:left'> 0.01548576</td><td style='text-align:left'>(2.03%)</td><td style='text-align:left'>0.4</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>Vth</td><td style='text-align:left'> 1.11626057</td><td style='text-align:left'> 0.00293409</td><td style='text-align:left'>(0.26%)</td><td style='text-align:left'>1.0797284388964827</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>L</td><td style='text-align:left'> 3.6000e-06</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>3.6e-06</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr><tr><td style='text-align:left'>c</td><td style='text-align:left'> 5.3000e-15</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>5.3e-15</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>False</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>Rs</td><td style='text-align:left'>mu</td><td style='text-align:right'>+0.7981</td></tr><tr><td style='text-align:left'>mu</td><td style='text-align:left'>Vth</td><td style='text-align:right'>+0.4774</td></tr><tr><td style='text-align:left'>Rs</td><td style='text-align:left'>Vth</td><td style='text-align:right'>+0.2994</td></tr></table>

# %% [markdown]
# # All in one go

# %%
#If you know all your parameters in advance, and the fitting is working well, you can batch process results.
data=np.loadtxt('exampledata.dat')
Vg=data[0]
G=data[1]*7.748091729e-5
smoothing=0.1
Vmin=-4
Vmax=4
L = 3.6e-6
C = 5.3e-15
CperA=C/(L*280e-9)
initial_Rs = 10000
initial_mu = 0.4

datadict,paramdict=ma.perform_entire_prodecure(Vg,G,smoothing,Vmin,Vmax,L,C,CperA,initial_Rs,initial_mu,plotting=True)

#The function returns two dictionaries; one with all the data, and one with all the parameters, just like in the GUI.
# Out:
# C:\git\MobilityApp\mobilityapp\supportfunctions.py:210: RuntimeWarning: divide by zero encountered in divide
#   mu_eff=L**2/(C*(Vg-V0)*((1/G)-Rs))

# %% [markdown]
# # For the very curious (or frustrated?!)

# %%
# Here are the functions used throughout, if you should need to edit them
# You will need to import from lmfit
from lmfit import Model, Parameters, minimize
